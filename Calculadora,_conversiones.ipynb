# %%
print("Que conversion deseas:")
print("1.-Longitud")
print("2.-Temperatura")
print("3.-Masa")
print("4.-Volumen")
print("5.-Tiempo")

Var1=int(input())
if(Var1==1):
    print("Que unidades quieres convertir:")
    print("1.-cm/pulgadas")
    print("2.-m/pies")
    print("3.-m/pulgadas")
    print("4.-m/millas")
    print("5.-Km/yardas")
    print("6.-Km/millas")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/2.54
        print("Resultado de cm a pulgadas es: ",y)
    
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*3.281
        print("Resultado de m a pies es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*39.37
        print("Resultado de m a pulgadas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==4):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1609
        print("Resultado de m a millas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==5):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1094
        print("Resultado de Km a Yardas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==6):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1.609
        print("Resultado de Km a millas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==2):
    print("Que unidades quiere convertir:")
    print("1.-celsius/farenheit")
    print("2.-celsius/kelvin")
    print("3.-kelvin/farenheit")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=(cantidad(9/5))+32
        print(cantidad,"resultado de °C a Farenheit es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad+273.15
        print("Resultado de °C a Kelvin es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=((cantidad-273.15)*(9/5))+32
        print("Resultado de °K a Farenheit es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
elif(Var1==3):
    print("Que unidades quiere convertir: ")
    print("1.-Kg/Libras")
    print("2.-Gramos/Onzas")
    print("3.-Kg/Toneladas")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*2.205
        print("Resultado de Kg a Libras es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/28.35
        print("Resultado de g a Onzas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1000
        print("Resultado de Kg a Toneladas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==4):
    print("Que unidades quiere convertir: ")
    print("1.-litro/galon")
    print("2.-m^3/yd^3")
    print("3.-m^3/pulgada^3")
    print("4.-m^3/pies^3")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*3.785
        print("Resultado de lt a Galon es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1.308
        print("Resultado de m^3 a Yd^3 es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1.308
        print("Resultado de m^3 a pulgada^3 es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==4):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*35.315
        print("Resultado de m^3 a pies^3 es: ",y)
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==5):
    print("Que unidades quiere convertir: ")
    print("1.-Horas/Minutos")
    print("2.-Minutos/Segundos")
    print("3.-Segundos/Milisegundos")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*60
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*60
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1000
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
# Out:
# Que conversion deseas:
# 1.-Longitud
# 2.-Temperatura
# 3.-Masa
# 4.-Volumen
# 5.-Tiempo
# 1
# Que unidades quieres convertir:
# 1.-cm/pulgadas
# 2.-m/pies
# 3.-m/pulgadas
# 4.-m/millas
# 5.-Km/yardas
# 6.-Km/millas
# 2
# Ingresa la cantidad:
# 23
# Resultado de m a pies es:  75.46300000000001

# %%
print("Que conversion deseas:")
print("1.-Longitud")
print("2.-Temperatura")
print("3.-Masa")
print("4.-Volumen")
print("5.-Tiempo")

Var1=int(input())
if(Var1==1):
    print("Que unidades quieres convertir:")
    print("1.-cm/pulgadas")
    print("2.-m/pies")
    print("3.-m/pulgadas")
    print("4.-m/millas")
    print("5.-Km/yardas")
    print("6.-Km/millas")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/2.54
        print("Resultado de cm a pulgadas es: ",y)
    
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*3.281
        print("Resultado de m a pies es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*39.37
        print("Resultado de m a pulgadas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==4):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1609
        print("Resultado de m a millas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==5):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1094
        print("Resultado de Km a Yardas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==6):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1.609
        print("Resultado de Km a millas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==2):
    print("Que unidades quiere convertir:")
    print("1.-celsius/farenheit")
    print("2.-celsius/kelvin")
    print("3.-kelvin/farenheit")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=(cantidad(9/5))+32
        print(cantidad,"resultado de °C a Farenheit es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad+273.15
        print("Resultado de °C a Kelvin es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=((cantidad-273.15)*(9/5))+32
        print("Resultado de °K a Farenheit es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
elif(Var1==3):
    print("Que unidades quiere convertir: ")
    print("1.-Kg/Libras")
    print("2.-Gramos/Onzas")
    print("3.-Kg/Toneladas")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*2.205
        print("Resultado de Kg a Libras es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/28.35
        print("Resultado de g a Onzas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1000
        print("Resultado de Kg a Toneladas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==4):
    print("Que unidades quiere convertir: ")
    print("1.-litro/galon")
    print("2.-m^3/yd^3")
    print("3.-m^3/pulgada^3")
    print("4.-m^3/pies^3")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*3.785
        print("Resultado de lt a Galon es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1.308
        print("Resultado de m^3 a Yd^3 es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1.308
        print("Resultado de m^3 a pulgada^3 es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==4):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*35.315
        print("Resultado de m^3 a pies^3 es: ",y)
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==5):
    print("Que unidades quiere convertir: ")
    print("1.-Horas/Minutos")
    print("2.-Minutos/Segundos")
    print("3.-Segundos/Milisegundos")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*60
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*60
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1000
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()

# %%
print("Que conversion deseas:")
print("1.-Longitud")
print("2.-Temperatura")
print("3.-Masa")
print("4.-Volumen")
print("5.-Tiempo")

Var1=int(input())
if(Var1==1):
    print("Que unidades quieres convertir:")
    print("1.-cm/pulgadas")
    print("2.-m/pies")
    print("3.-m/pulgadas")
    print("4.-m/millas")
    print("5.-Km/yardas")
    print("6.-Km/millas")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/2.54
        print("Resultado de cm a pulgadas es: ",y)
    
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*3.281
        print("Resultado de m a pies es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*39.37
        print("Resultado de m a pulgadas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==4):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1609
        print("Resultado de m a millas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==5):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1094
        print("Resultado de Km a Yardas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==6):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1.609
        print("Resultado de Km a millas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==2):
    print("Que unidades quiere convertir:")
    print("1.-celsius/farenheit")
    print("2.-celsius/kelvin")
    print("3.-kelvin/farenheit")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=(cantidad(9/5))+32
        print(cantidad,"resultado de °C a Farenheit es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad+273.15
        print("Resultado de °C a Kelvin es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=((cantidad-273.15)*(9/5))+32
        print("Resultado de °K a Farenheit es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
        
elif(Var1==3):
    print("Que unidades quiere convertir: ")
    print("1.-Kg/Libras")
    print("2.-Gramos/Onzas")
    print("3.-Kg/Toneladas")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*2.205
        print("Resultado de Kg a Libras es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/28.35
        print("Resultado de g a Onzas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad/1000
        print("Resultado de Kg a Toneladas es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==4):
    print("Que unidades quiere convertir: ")
    print("1.-litro/galon")
    print("2.-m^3/yd^3")
    print("3.-m^3/pulgada^3")
    print("4.-m^3/pies^3")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*3.785
        print("Resultado de lt a Galon es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1.308
        print("Resultado de m^3 a Yd^3 es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1.308
        print("Resultado de m^3 a pulgada^3 es: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==4):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*35.315
        print("Resultado de m^3 a pies^3 es: ",y)
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
elif(Var1==5):
    print("Que unidades quiere convertir: ")
    print("1.-Horas/Minutos")
    print("2.-Minutos/Segundos")
    print("3.-Segundos/Milisegundos")

    Var2=int(input())
    if(Var2==1):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*60
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==2):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*60
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
        
    elif(Var2==3):
        print("Ingresa la cantidad: ")
        cantidad=float(input())
        y=cantidad*1000
        print("Resultado: ",y)
        
        H=open('Resultado de la Conversion.txt','a') 
        H.write(str(y))
        H.close()
# Out:
# Que conversion deseas:
# 1.-Longitud
# 2.-Temperatura
# 3.-Masa
# 4.-Volumen
# 5.-Tiempo
# 1
# Que unidades quieres convertir:
# 1.-cm/pulgadas
# 2.-m/pies
# 3.-m/pulgadas
# 4.-m/millas
# 5.-Km/yardas
# 6.-Km/millas
# 1
# Ingresa la cantidad:
# 23
# Resultado de cm a pulgadas es:  9.05511811023622
